# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '/home/anna/ResultsSignalDA/MIAvalidation_olddataset/reconstruction//MIAstyleLinear__2022-12-09//Reconstructions/real_0_linear_signal_with_denoise//real_0_linear_signal_with_denoise.h5'
i = 30
f_handle = h5py.File(filename, 'r')
rec = f_handle['BackProjection']
plt.imshow(rec[i])

# %%
filename =  '/home/anna/ResultsSignalDA/MIAvalidation_olddataset/Benchmark_LinearGT_BP//Reconstructions/arm_linear_sigmat_multisegment//arm_linear_sigmat_multisegment.h5'

f_handle = h5py.File(filename, 'r')
rec = f_handle['BackProjection']
plt.imshow(rec[i])
